# %% [markdown]
# # Supervised learning with clustering

# %%
import os,time
os.environ["OPENBLAS_NUM_THREADS"] = "32"
os.environ["OMP_NUM_THREADS"] = "4"

import pandas as pd
import numpy as np
import random
# We use a custom hot encoder for performances reasons.
from codpy.data_processing import hot_encoder
# Standard codpy kernel class.
from codpy.kernel import Kernel
# A multi scale kernel method.
from codpy.multiscale_kernel import *
from codpy.kernel import KernelClassifier
from sklearn.metrics import confusion_matrix

# %%
def get_MNIST_data(N=-1):
    import tensorflow as tf

    (x, fx), (z, fz) = tf.keras.datasets.mnist.load_data()
    x, z = x / 255.0, z / 255.0
    x, z, fx, fz = (
        x.reshape(len(x), -1),
        z.reshape(len(z), -1),
        fx.reshape(len(fx), -1),
        fz.reshape(len(fz), -1),
    )
    fx, fz = (
        hot_encoder(pd.DataFrame(data=fx), cat_cols_include=[0], sort_columns=True),
        hot_encoder(pd.DataFrame(data=fz), cat_cols_include=[0], sort_columns=True),
    )
    x, fx, z, fz = (x, fx.values, z, fz.values)
    if N != -1:
        indices = random.sample(range(x.shape[0]), N)
        x, fx = x[indices], fx[indices]

    return x, fx, z, fz




def one_experiment(N_partition,get_predictor):
    def get_score(predictor):
        f_z = predictor(z)
        f_z = f_z.argmax(axis=-1)
        ground_truth = fz.argmax(axis=-1)
        out = confusion_matrix(ground_truth, f_z)
        return np.trace(out) / np.sum(out)

    elapsed_time = time.time()
    predictor = get_predictor(N_partition)
    score = get_score(predictor)
    elapsed_time = time.time()-elapsed_time
    return score, elapsed_time

def run_experiment(N_partitions,get_predictors,labels,file_name=None):

    results=[]
    for N_partition in N_partitions:
        for get_predictor,label in zip(get_predictors,labels):
            score, elapsed_time = one_experiment(N_partition,get_predictor)
            print("Method:",label,"N_partition:",N_partition," score:",score," time:",elapsed_time)
            results.append(
                {
                    "Ny": N_partition,
                    "Method": label,
                    "Execution Time (s)": elapsed_time,
                    "score": score
                }
    )
    out =   pd.DataFrame(results)
    print(out)
    if file_name is not None: out.to_csv(file_name)
    return out


class Random_clusters:
    def __init__(self,x, N, max_iter = 300, random_state = 42,batch_size = 1024,verbose = False,**kwargs):
        self.x = x
        self.indices = random.sample(range(self.x.shape[0]), N)
        self.cluster_centers_ = self.x[self.indices]
    def __call__(self,z, **kwargs):
        return self.distance(z,self.cluster_centers_).argmin(axis=1)
    def distance(self,x,y):
        return core.op.Dnm(x, y, distance="norm22")


class KernelClusteringClassifierXY(KernelClassifier):
    def __init__(self,x,N,clustering_method,fx,**kwargs):
        method = clustering_method(x,N,fx=fx,**kwargs)
        y = method.cluster_centers_
        # fy = fx[method.indices]
        super().__init__(x=x,y=y,fx=fx,**kwargs)

class KernelClusteringClassifierYY(KernelClassifier):
    def __init__(self,x,N,clustering_method,fx,**kwargs):
        method = clustering_method(x,N,fx=fx,**kwargs)
        y = method.cluster_centers_
        fy = fx[method.indices]
        super().__init__(x=y,fx=fy,**kwargs)

# %%
N_partitions=[16,32,64,128,256,512,1024,2048,4096,8192]
N_MNIST_pics=-1
x, fx, z, fz = get_MNIST_data(N_MNIST_pics)
core.kernel_interface.set_verbose(False)
# labels = ["random","Greedy","K-Means","Sharp Disc."]
labels = ["random","Greedy","K-Means"]
get_predictorsXY = [
    lambda N_partition: KernelClusteringClassifierXY(x=x,fx=fx,N=N_partition,clustering_method=Random_clusters),
    lambda N_partition: KernelClassifier().greedy_select(x=x,fx=fx,N=N_partition,all=True),
    lambda N_partition: KernelClusteringClassifierXY(x=x,fx=fx,N=N_partition,clustering_method=MiniBatchkmeans)
    # lambda N_partition: KernelClusteringClassifier(x=x,fx=fx,N=N_partition,clustering_method=SharpDiscrepancy),
]
get_predictorsYY = [
    lambda N_partition: KernelClusteringClassifierYY(x=x,fx=fx,N=N_partition,clustering_method=Random_clusters),
    lambda N_partition: KernelClassifier().greedy_select(x=x,fx=fx,N=N_partition,all=False),
    lambda N_partition: KernelClusteringClassifierYY(x=x,fx=fx,N=N_partition,clustering_method=MiniBatchkmeans)
    # lambda N_partition: KernelClusteringClassifier(x=x,fx=fx,N=N_partition,clustering_method=SharpDiscrepancy),
]

# Select a multi scale kernel method where the centers are given by a k-mean algorithm.
core.kernel_interface.set_verbose()
run_experiment(N_partitions=N_partitions,get_predictors=get_predictorsXY,labels=labels,file_name = os.path.join("figs_data", "results_MNISTXY.csv"))
run_experiment(N_partitions=N_partitions,get_predictors=get_predictorsYY,labels=labels,file_name = os.path.join("figs_data", "results_MNISTYY.csv"))
# Out:
# Method: random N_partition: 16  score: 0.6782  time: 5.259396076202393
# Method: Greedy N_partition: 16  score: 0.729  time: 9.436028480529785
# Method: K-Means N_partition: 16  score: 0.7617  time: 8.071195840835571
# Method: random N_partition: 32  score: 0.8004  time: 4.586090087890625
# Method: Greedy N_partition: 32  score: 0.8039  time: 11.987001180648804
# Method: K-Means N_partition: 32  score: 0.8583  time: 9.36504054069519
# Method: random N_partition: 64  score: 0.8436  time: 4.517632722854614
# Method: Greedy N_partition: 64  score: 0.8649  time: 13.059160232543945
# Method: K-Means N_partition: 64  score: 0.9036  time: 8.68225359916687
# Method: random N_partition: 128  score: 0.9041  time: 6.766138553619385
# Method: Greedy N_partition: 128  score: 0.909  time: 28.141050100326538
# Method: K-Means N_partition: 128  score: 0.9284  time: 31.383917331695557
# Method: random N_partition: 256  score: 0.9292  time: 13.627364158630371
# Method: Greedy N_partition: 256  score: 0.9367  time: 45.974021911621094
# Method: K-Means N_partition: 256  score: 0.9474  time: 23.654725551605225
# Method: random N_partition: 512  score: 0.9492  time: 15.016795635223389
# Method: Greedy N_partition: 512  score: 0.953  time: 45.1273353099823
# Method: K-Means N_partition: 512  score: 0.9608  time: 62.198166370391846
# Method: random N_partition: 1024  score: 0.9586  time: 42.77094793319702
# Method: Greedy N_partition: 1024  score: 0.9655  time: 96.0299060344696
# Method: K-Means N_partition: 1024  score: 0.9685  time: 103.31748843193054
# Method: random N_partition: 2048  score: 0.9685  time: 76.2785964012146
# Method: Greedy N_partition: 2048  score: 0.9749  time: 273.87095856666565
# Method: K-Means N_partition: 2048  score: 0.9763  time: 179.94193124771118
# Method: random N_partition: 4096  score: 0.9726  time: 134.9647238254547
# Method: Greedy N_partition: 4096  score: 0.9811  time: 504.57132363319397
# Method: K-Means N_partition: 4096  score: 0.9793  time: 706.3099844455719
# Method: random N_partition: 8192  score: 0.9779  time: 314.8740568161011
# Method: Greedy N_partition: 8192  score: 0.9844  time: 702.7004239559174
# Method: K-Means N_partition: 8192  score: 0.9826  time: 811.5951693058014
#       Ny   Method  Execution Time (s)   score
# 0     16   random            5.259396  0.6782
# 1     16   Greedy            9.436028  0.7290
# 2     16  K-Means            8.071196  0.7617
# 3     32   random            4.586090  0.8004
# 4     32   Greedy           11.987001  0.8039
# 5     32  K-Means            9.365041  0.8583
# 6     64   random            4.517633  0.8436
# 7     64   Greedy           13.059160  0.8649
# 8     64  K-Means            8.682254  0.9036
# 9    128   random            6.766139  0.9041
# 10   128   Greedy           28.141050  0.9090
# 11   128  K-Means           31.383917  0.9284
# 12   256   random           13.627364  0.9292
# 13   256   Greedy           45.974022  0.9367
# 14   256  K-Means           23.654726  0.9474
# 15   512   random           15.016796  0.9492
# 16   512   Greedy           45.127335  0.9530
# 17   512  K-Means           62.198166  0.9608
# 18  1024   random           42.770948  0.9586
# 19  1024   Greedy           96.029906  0.9655
# 20  1024  K-Means          103.317488  0.9685
# 21  2048   random           76.278596  0.9685
# 22  2048   Greedy          273.870959  0.9749
# 23  2048  K-Means          179.941931  0.9763
# 24  4096   random          134.964724  0.9726
# 25  4096   Greedy          504.571324  0.9811
# 26  4096  K-Means          706.309984  0.9793
# 27  8192   random          314.874057  0.9779
# 28  8192   Greedy          702.700424  0.9844
# 29  8192  K-Means          811.595169  0.9826
# Method: random N_partition: 16  score: 0.359  time: 0.31073546409606934
# Method: Greedy N_partition: 16  score: 0.4338  time: 3.3882110118865967
# Method: K-Means N_partition: 16  score: 0.6152  time: 1.5731992721557617
# Method: random N_partition: 32  score: 0.5019  time: 0.38060832023620605
# Method: Greedy N_partition: 32  score: 0.3579  time: 4.1209800243377686
# Method: K-Means N_partition: 32  score: 0.7363  time: 2.1600632667541504
# Method: random N_partition: 64  score: 0.5918  time: 0.38509559631347656
# Method: Greedy N_partition: 64  score: 0.5031  time: 5.172212362289429
# Method: K-Means N_partition: 64  score: 0.7533  time: 3.001753807067871
# Method: random N_partition: 128  score: 0.7686  time: 0.49840283393859863
# Method: Greedy N_partition: 128  score: 0.6582  time: 7.22046160697937
# Method: K-Means N_partition: 128  score: 0.799  time: 4.383035182952881
# Method: random N_partition: 256  score: 0.8449  time: 0.8427829742431641
# Method: Greedy N_partition: 256  score: 0.7914  time: 10.870336532592773
# Method: K-Means N_partition: 256  score: 0.8348  time: 6.862383127212524
# Method: random N_partition: 512  score: 0.8918  time: 1.3655381202697754
# Method: Greedy N_partition: 512  score: 0.8844  time: 18.367263078689575
# Method: K-Means N_partition: 512  score: 0.8652  time: 12.614454507827759
# Method: random N_partition: 1024  score: 0.9297  time: 2.697705030441284
# Method: Greedy N_partition: 1024  score: 0.9542  time: 34.23953652381897
# Method: K-Means N_partition: 1024  score: 0.9147  time: 25.224133253097534
# Method: random N_partition: 2048  score: 0.9477  time: 5.845489501953125
# Method: Greedy N_partition: 2048  score: 0.978  time: 71.80454134941101
# Method: K-Means N_partition: 2048  score: 0.9445  time: 50.43032479286194
# Method: random N_partition: 4096  score: 0.9604  time: 15.396459102630615
# Method: Greedy N_partition: 4096  score: 0.9857  time: 170.8448133468628
# Method: K-Means N_partition: 4096  score: 0.9589  time: 178.87265038490295
# Method: random N_partition: 8192  score: 0.969  time: 54.85795187950134
# Method: Greedy N_partition: 8192  score: 0.986  time: 483.8823175430298
# Method: K-Means N_partition: 8192  score: 0.9705  time: 825.0051786899567
#       Ny   Method  Execution Time (s)   score
# 0     16   random            0.310735  0.3590
# 1     16   Greedy            3.388211  0.4338
# 2     16  K-Means            1.573199  0.6152
# 3     32   random            0.380608  0.5019
# 4     32   Greedy            4.120980  0.3579
# 5     32  K-Means            2.160063  0.7363
# 6     64   random            0.385096  0.5918
# 7     64   Greedy            5.172212  0.5031
# 8     64  K-Means            3.001754  0.7533
# 9    128   random            0.498403  0.7686
# 10   128   Greedy            7.220462  0.6582
# 11   128  K-Means            4.383035  0.7990
# 12   256   random            0.842783  0.8449
# 13   256   Greedy           10.870337  0.7914
# 14   256  K-Means            6.862383  0.8348
# 15   512   random            1.365538  0.8918
# 16   512   Greedy           18.367263  0.8844
# 17   512  K-Means           12.614455  0.8652
# 18  1024   random            2.697705  0.9297
# 19  1024   Greedy           34.239537  0.9542
# 20  1024  K-Means           25.224133  0.9147
# 21  2048   random            5.845490  0.9477
# 22  2048   Greedy           71.804541  0.9780
# 23  2048  K-Means           50.430325  0.9445
# 24  4096   random           15.396459  0.9604
# 25  4096   Greedy          170.844813  0.9857
# 26  4096  K-Means          178.872650  0.9589
# 27  8192   random           54.857952  0.9690
# 28  8192   Greedy          483.882318  0.9860
# 29  8192  K-Means          825.005179  0.9705
#       Ny   Method  Execution Time (s)   score
# 0     16   random            0.310735  0.3590
# 1     16   Greedy            3.388211  0.4338
# 2     16  K-Means            1.573199  0.6152
# 3     32   random            0.380608  0.5019
# 4     32   Greedy            4.120980  0.3579
# 5     32  K-Means            2.160063  0.7363
# 6     64   random            0.385096  0.5918
# 7     64   Greedy            5.172212  0.5031
# 8     64  K-Means            3.001754  0.7533
# 9    128   random            0.498403  0.7686
# 10   128   Greedy            7.220462  0.6582
# 11   128  K-Means            4.383035  0.7990
# 12   256   random            0.842783  0.8449
# 13   256   Greedy           10.870337  0.7914
# 14   256  K-Means            6.862383  0.8348
# 15   512   random            1.365538  0.8918
# 16   512   Greedy           18.367263  0.8844
# 17   512  K-Means           12.614455  0.8652
# 18  1024   random            2.697705  0.9297
# 19  1024   Greedy           34.239537  0.9542
# 20  1024  K-Means           25.224133  0.9147
# 21  2048   random            5.845490  0.9477
# 22  2048   Greedy           71.804541  0.9780
# 23  2048  K-Means           50.430325  0.9445
# 24  4096   random           15.396459  0.9604
# 25  4096   Greedy          170.844813  0.9857
# 26  4096  K-Means          178.872650  0.9589
# 27  8192   random           54.857952  0.9690
# 28  8192   Greedy          483.882318  0.9860
# 29  8192  K-Means          825.005179  0.9705
