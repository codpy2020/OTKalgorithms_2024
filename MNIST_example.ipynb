# %% [markdown]
# # Supervised learning with clustering

# %%
import os,time
os.environ["OPENBLAS_NUM_THREADS"] = "32"
os.environ["OMP_NUM_THREADS"] = "4"

import pandas as pd
import numpy as np
import random
# We use a custom hot encoder for performances reasons.
from codpy.data_processing import hot_encoder
# Standard codpy kernel class.
from codpy.kernel import Kernel
# A multi scale kernel method.
from codpy.multiscale_kernel import *
from codpy.kernel import KernelClassifier
from sklearn.metrics import confusion_matrix

# %%
def get_MNIST_data(N=-1):
    import tensorflow as tf

    (x, fx), (z, fz) = tf.keras.datasets.mnist.load_data()
    x, z = x / 255.0, z / 255.0
    x, z, fx, fz = (
        x.reshape(len(x), -1),
        z.reshape(len(z), -1),
        fx.reshape(len(fx), -1),
        fz.reshape(len(fz), -1),
    )
    fx, fz = (
        hot_encoder(pd.DataFrame(data=fx), cat_cols_include=[0], sort_columns=True),
        hot_encoder(pd.DataFrame(data=fz), cat_cols_include=[0], sort_columns=True),
    )
    x, fx, z, fz = (x, fx.values, z, fz.values)
    if N != -1:
        indices = random.sample(range(x.shape[0]), N)
        x, fx = x[indices], fx[indices]

    return x, fx, z, fz




def one_experiment(N_partition,get_predictor):
    def get_score(predictor):
        f_z = predictor(z)
        f_z = f_z.argmax(axis=-1)
        ground_truth = fz.argmax(axis=-1)
        out = confusion_matrix(ground_truth, f_z)
        return np.trace(out) / np.sum(out)

    elapsed_time = time.time()
    predictor = get_predictor(N_partition)
    score = get_score(predictor)
    elapsed_time = time.time()-elapsed_time
    return score, elapsed_time

def run_experiment(N_partitions,get_predictors,labels,file_name=None):

    results=[]
    for N_partition in N_partitions:
        for get_predictor,label in zip(get_predictors,labels):
            score, elapsed_time = one_experiment(N_partition,get_predictor)
            print("Method:",label,"N_partition:",N_partition," score:",score," time:",elapsed_time)
            results.append(
                {
                    "Ny": N_partition,
                    "Method": label,
                    "Execution Time (s)": elapsed_time,
                    "score": score
                }
    )
    out =   pd.DataFrame(results)
    print(out)
    if file_name is not None: out.to_csv(file_name)
    return out


class Random_clusters:
    def __init__(self,x, N, max_iter = 300, random_state = 42,batch_size = 1024,verbose = False,**kwargs):
        self.x = x
        self.indices = random.sample(range(self.x.shape[0]), N)
        self.cluster_centers_ = self.x[self.indices]
    def __call__(self,z, **kwargs):
        return self.distance(z,self.cluster_centers_).argmin(axis=1)
    def distance(self,x,y):
        return core.op.Dnm(x, y, distance="norm22")


class KernelClusteringClassifierXY(KernelClassifier):
    def __init__(self,x,N,clustering_method,fx,**kwargs):
        method = clustering_method(x,N,fx=fx,**kwargs)
        y = method.cluster_centers_
        # fy = fx[method.indices]
        super().__init__(x=x,y=y,fx=fx,**kwargs)

class KernelClusteringClassifierYY(KernelClassifier):
    def __init__(self,x,N,clustering_method,fx,**kwargs):
        method = clustering_method(x,N,fx=fx,**kwargs)
        y = method.cluster_centers_
        fy = fx[method.indices]
        super().__init__(x=y,fx=fy,**kwargs)

# %%
N_partitions=[16,32,64,128,256,512,1024,2048,4096,8192]
N_MNIST_pics=-1
x, fx, z, fz = get_MNIST_data(N_MNIST_pics)
# labels = ["random","Greedy","K-Means","Sharp Disc."]
labels = ["random","Greedy","K-Means"]
get_predictorsXY = [
    lambda N_partition: KernelClusteringClassifierXY(x=x,fx=fx,N=N_partition,clustering_method=Random_clusters),
    lambda N_partition: KernelClassifier().greedy_select(x=x,fx=fx,N=N_partition,all=True),
    lambda N_partition: KernelClusteringClassifierXY(x=x,fx=fx,N=N_partition,clustering_method=MiniBatchkmeans)
    # lambda N_partition: KernelClusteringClassifier(x=x,fx=fx,N=N_partition,clustering_method=SharpDiscrepancy),
]
get_predictorsYY = [
    lambda N_partition: KernelClusteringClassifierYY(x=x,fx=fx,N=N_partition,clustering_method=Random_clusters),
    lambda N_partition: KernelClassifier().greedy_select(x=x,fx=fx,N=N_partition,all=False),
    lambda N_partition: KernelClusteringClassifierYY(x=x,fx=fx,N=N_partition,clustering_method=MiniBatchkmeans)
    # lambda N_partition: KernelClusteringClassifier(x=x,fx=fx,N=N_partition,clustering_method=SharpDiscrepancy),
]

# Select a multi scale kernel method where the centers are given by a k-mean algorithm.
core.kernel_interface.set_verbose()
run_experiment(N_partitions=N_partitions,get_predictors=get_predictorsXY,labels=labels,file_name = os.path.join("figs_data", "results_MNISTXY.csv"))
run_experiment(N_partitions=N_partitions,get_predictors=get_predictorsYY,labels=labels,file_name = os.path.join("figs_data", "results_MNISTYY.csv"))
# Out:
# Method: random N_partition: 16  score: 0.6864  time: 2.1320793628692627
# Method: Greedy N_partition: 16  score: 0.7102  time: 3.8123178482055664
# Method: K-Means N_partition: 16  score: 0.7621  time: 2.8301477432250977
# Method: random N_partition: 32  score: 0.8165  time: 2.165266275405884
# Method: Greedy N_partition: 32  score: 0.8161  time: 4.144433975219727
# Method: K-Means N_partition: 32  score: 0.8584  time: 3.1011850833892822
# Method: random N_partition: 64  score: 0.8602  time: 2.313924551010132
# Method: Greedy N_partition: 64  score: 0.8671  time: 4.809885501861572
# Method: K-Means N_partition: 64  score: 0.9031  time: 3.487732172012329
# Method: random N_partition: 128  score: 0.9073  time: 2.6176884174346924
# Method: Greedy N_partition: 128  score: 0.9137  time: 5.972937822341919
# Method: K-Means N_partition: 128  score: 0.9284  time: 4.213956356048584
# Method: random N_partition: 256  score: 0.9352  time: 3.231015682220459
# Method: Greedy N_partition: 256  score: 0.9357  time: 8.10653567314148
# Method: K-Means N_partition: 256  score: 0.9476  time: 5.575385570526123
# Method: random N_partition: 512  score: 0.9469  time: 4.596044063568115
# Method: Greedy N_partition: 512  score: 0.9514  time: 12.614920854568481
# Method: K-Means N_partition: 512  score: 0.9608  time: 9.182316064834595
# Method: random N_partition: 1024  score: 0.9587  time: 8.790472984313965
# Method: Greedy N_partition: 1024  score: 0.9622  time: 25.72767686843872
# Method: K-Means N_partition: 1024  score: 0.9685  time: 18.216662645339966
# Method: random N_partition: 2048  score: 0.9669  time: 18.697730779647827
# Method: Greedy N_partition: 2048  score: 0.9736  time: 55.63443922996521
# Method: K-Means N_partition: 2048  score: 0.9761  time: 35.00087761878967
# Method: random N_partition: 4096  score: 0.9739  time: 47.690202951431274
# Method: Greedy N_partition: 4096  score: 0.9812  time: 141.50323820114136
# Method: K-Means N_partition: 4096  score: 0.9792  time: 102.86853981018066
# Method: random N_partition: 8192  score: 0.9771  time: 147.32418012619019
# Method: Greedy N_partition: 8192  score: 0.9841  time: 422.551540851593
# Method: K-Means N_partition: 8192  score: 0.9838  time: 324.55020403862
#       Ny   Method  Execution Time (s)   score
# 0     16   random            2.132079  0.6864
# 1     16   Greedy            3.812318  0.7102
# 2     16  K-Means            2.830148  0.7621
# 3     32   random            2.165266  0.8165
# 4     32   Greedy            4.144434  0.8161
# 5     32  K-Means            3.101185  0.8584
# 6     64   random            2.313925  0.8602
# 7     64   Greedy            4.809886  0.8671
# 8     64  K-Means            3.487732  0.9031
# 9    128   random            2.617688  0.9073
# 10   128   Greedy            5.972938  0.9137
# 11   128  K-Means            4.213956  0.9284
# 12   256   random            3.231016  0.9352
# 13   256   Greedy            8.106536  0.9357
# 14   256  K-Means            5.575386  0.9476
# 15   512   random            4.596044  0.9469
# 16   512   Greedy           12.614921  0.9514
# 17   512  K-Means            9.182316  0.9608
# 18  1024   random            8.790473  0.9587
# 19  1024   Greedy           25.727677  0.9622
# 20  1024  K-Means           18.216663  0.9685
# 21  2048   random           18.697731  0.9669
# 22  2048   Greedy           55.634439  0.9736
# 23  2048  K-Means           35.000878  0.9761
# 24  4096   random           47.690203  0.9739
# 25  4096   Greedy          141.503238  0.9812
# 26  4096  K-Means          102.868540  0.9792
# 27  8192   random          147.324180  0.9771
# 28  8192   Greedy          422.551541  0.9841
# 29  8192  K-Means          324.550204  0.9838
# Method: random N_partition: 16  score: 0.4769  time: 0.2072744369506836
# Method: Greedy N_partition: 16  score: 0.4221  time: 2.679048776626587
# Method: K-Means N_partition: 16  score: 0.6196  time: 1.0748755931854248
# Method: random N_partition: 32  score: 0.5788  time: 0.22724604606628418
# Method: Greedy N_partition: 32  score: 0.377  time: 3.0189921855926514
# Method: K-Means N_partition: 32  score: 0.7369  time: 1.3326830863952637
# Method: random N_partition: 64  score: 0.7165  time: 0.2514801025390625
# Method: Greedy N_partition: 64  score: 0.5372  time: 3.5595271587371826
# Method: K-Means N_partition: 64  score: 0.7551  time: 1.7016258239746094
# Method: random N_partition: 128  score: 0.7513  time: 0.29004788398742676
# Method: Greedy N_partition: 128  score: 0.6277  time: 4.563542366027832
# Method: K-Means N_partition: 128  score: 0.7987  time: 2.152111530303955
# Method: random N_partition: 256  score: 0.8605  time: 0.3794441223144531
# Method: Greedy N_partition: 256  score: 0.7856  time: 6.3132164478302
# Method: K-Means N_partition: 256  score: 0.8348  time: 3.269761323928833
# Method: random N_partition: 512  score: 0.8981  time: 0.560842752456665
# Method: Greedy N_partition: 512  score: 0.8931  time: 9.933112621307373
# Method: K-Means N_partition: 512  score: 0.8646  time: 5.442217588424683
# Method: random N_partition: 1024  score: 0.9226  time: 1.042405366897583
# Method: Greedy N_partition: 1024  score: 0.9485  time: 18.34449028968811
# Method: K-Means N_partition: 1024  score: 0.9155  time: 10.245938301086426
# Method: random N_partition: 2048  score: 0.9447  time: 2.1636524200439453
# Method: Greedy N_partition: 2048  score: 0.9784  time: 38.86636161804199
# Method: K-Means N_partition: 2048  score: 0.9449  time: 18.469666242599487
# Method: random N_partition: 4096  score: 0.9592  time: 6.36962366104126
# Method: Greedy N_partition: 4096  score: 0.9852  time: 97.6025562286377
# Method: K-Means N_partition: 4096  score: 0.959  time: 62.9512414932251
# Method: random N_partition: 8192  score: 0.967  time: 28.56475329399109
# Method: Greedy N_partition: 8192  score: 0.9864  time: 290.5955412387848
# Method: K-Means N_partition: 8192  score: 0.9709  time: 211.7602982521057
#       Ny   Method  Execution Time (s)   score
# 0     16   random            0.207274  0.4769
# 1     16   Greedy            2.679049  0.4221
# 2     16  K-Means            1.074876  0.6196
# 3     32   random            0.227246  0.5788
# 4     32   Greedy            3.018992  0.3770
# 5     32  K-Means            1.332683  0.7369
# 6     64   random            0.251480  0.7165
# 7     64   Greedy            3.559527  0.5372
# 8     64  K-Means            1.701626  0.7551
# 9    128   random            0.290048  0.7513
# 10   128   Greedy            4.563542  0.6277
# 11   128  K-Means            2.152112  0.7987
# 12   256   random            0.379444  0.8605
# 13   256   Greedy            6.313216  0.7856
# 14   256  K-Means            3.269761  0.8348
# 15   512   random            0.560843  0.8981
# 16   512   Greedy            9.933113  0.8931
# 17   512  K-Means            5.442218  0.8646
# 18  1024   random            1.042405  0.9226
# 19  1024   Greedy           18.344490  0.9485
# 20  1024  K-Means           10.245938  0.9155
# 21  2048   random            2.163652  0.9447
# 22  2048   Greedy           38.866362  0.9784
# 23  2048  K-Means           18.469666  0.9449
# 24  4096   random            6.369624  0.9592
# 25  4096   Greedy           97.602556  0.9852
# 26  4096  K-Means           62.951241  0.9590
# 27  8192   random           28.564753  0.9670
# 28  8192   Greedy          290.595541  0.9864
# 29  8192  K-Means          211.760298  0.9709
#       Ny   Method  Execution Time (s)   score
# 0     16   random            0.207274  0.4769
# 1     16   Greedy            2.679049  0.4221
# 2     16  K-Means            1.074876  0.6196
# 3     32   random            0.227246  0.5788
# 4     32   Greedy            3.018992  0.3770
# 5     32  K-Means            1.332683  0.7369
# 6     64   random            0.251480  0.7165
# 7     64   Greedy            3.559527  0.5372
# 8     64  K-Means            1.701626  0.7551
# 9    128   random            0.290048  0.7513
# 10   128   Greedy            4.563542  0.6277
# 11   128  K-Means            2.152112  0.7987
# 12   256   random            0.379444  0.8605
# 13   256   Greedy            6.313216  0.7856
# 14   256  K-Means            3.269761  0.8348
# 15   512   random            0.560843  0.8981
# 16   512   Greedy            9.933113  0.8931
# 17   512  K-Means            5.442218  0.8646
# 18  1024   random            1.042405  0.9226
# 19  1024   Greedy           18.344490  0.9485
# 20  1024  K-Means           10.245938  0.9155
# 21  2048   random            2.163652  0.9447
# 22  2048   Greedy           38.866362  0.9784
# 23  2048  K-Means           18.469666  0.9449
# 24  4096   random            6.369624  0.9592
# 25  4096   Greedy           97.602556  0.9852
# 26  4096  K-Means           62.951241  0.9590
# 27  8192   random           28.564753  0.9670
# 28  8192   Greedy          290.595541  0.9864
# 29  8192  K-Means          211.760298  0.9709
